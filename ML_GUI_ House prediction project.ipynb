# %%
#algorithm machine learning

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from PIL import Image,ImageTk


#from sklearn.datasets import load_Cleaned_data

import mysql.connector
import tkinter
from tkinter import messagebox

#GUI BASED MACHINE LEARNING MODEL

from tkinter import *
from tkinter import ttk
root=Tk()
root.geometry("800x600")
root.configure(background="light green")
root.title("House Price prediction using Machine learning project")
#photo=PhotoImage(file="butterfly.png")
root.iconbitmap('tt.ico')

# img = PhotoImage(file="ne.png")
# label = Label( root, image=img)
# label.place(x=0, y=0)

Label(root,text="Welcome To House price predictor ",font=('Helvetica',15,'bold'),width=100,bg="white",relief="solid").pack()
Label(root,text="Applcation version 1.1",bg="white",relief="solid").pack(side=BOTTOM,fill='both')
#Label(root,text="**********************************************************",bg="white").pack(fill='both')



#Entry Label
Label(root,text="Select The Location",bg="light green",width=20,relief="solid").place(x=220,y=100)
Label(root,text="Enter BHK",bg="light green",width=20,relief="solid").place(x=760,y=100)
Label(root,text="Enter Numbers Of Bathrooms",bg="light green",width=24,relief="solid").place(x=220,y=180)
Label(root,text="Enter Total Square Feet",bg="light green",width=20,relief="solid").place(x=760,y=180)
l1=Label(root,text="Result",bg="light green",width=20,relief="solid")
l1.place(x=480,y=260)

l2=Label(root,text="Predicted House Price",bg="light green",width=20,relief="ridge",font=('times new roman',16,'bold'))
l2.place(x=500,y=400)

l3=Label(root,text=" ",bg="white",width=60,height=4,font=('times new roman',14,'bold'))
l3.place(x=300,y=440)


#entry for flower specification
#entry for Sepal length
ln=StringVar()
bk=StringVar()
bm=StringVar()
ts=StringVar()

Entry(root,text=ln,width=25).place(x=400,y=100)
Entry(root,text=bk,width=25).place(x=940,y=100)
Entry(root,text=bm,width=25).place(x=420,y=180)
Entry(root,text=ts,width=25).place(x=940,y=180)

#information about flower
Label(root,text="Information",bg="light green",width=20,relief="solid").place(x=480,y=300)

def areainfo():
    n=Tk()
    n.geometry("800x600")
    n.configure(background="light green")
    Label(n, text="Information about Application", bg="light green",font=('Helvetica',15,'bold')).pack()
    data='''* House Area (Location) *
    other, Whitefield Sarjapur,  Road Electronic City, Kanakpura Road,Thanisandra ,                    
    Yelahanka, Uttarahalli, Hebbal, Marathahalli, Raja Rajeshwari Nagar,Hennur Road,                     
    Bannerghatta Road  ,7th Phase JP Nagar,Haralur Road ,
    Electronic City Phase II  ,Rajaji Nagar ,Chandapura,
    Bellandur ,KR Puram ,Electronics City Phase 1,        
    Hoodi ,Yeshwanthpur ,Begur Road ,
    Sarjapur  ,Kasavanhalli ,Harlur,                          
    Banashankari   ,Hormavu,Kengeri ,                                            
    Hosa Road ,JP Nagar ,Ramamurthy Nagar,
    Old Madras Road ,Jakkur ,Varthur,                          
    Kothanur ,Kaggadasapura ,Koramangala ,
    Nagarbhavi ,Thigalarapalya,Indira Nagar  ,
    Akshaya Nagar ,TC Palaya ,Balagere,       
    Rachenahalli ,Malleshwaram ,Hosur Road,   
    8th Phase JP Nagar,Hennur ,Gottigere , 
    Jigani,Budigere ,Bhoganhalli,
    HSR Layout  ,Jalahalli  ,Ramagondanahalli ,
    Chikkabanavar                    Cunningham Road                  
    Shampura                         Konanakunte                      
    Yelenahalli                      Mahalakshmi Layout               
    BEML Layout                      Dommasandra                      
    Gollarapalya Hosahalli           ITPL                             
    Sompura                          Doddaballapur                    
    Laggere                          Cox Town                         
    Vishwapriya Layout               Bharathi Nagar                   
    Badavala Nagar                   AECS Layout                      5th Block Hbr Layout             
    Banashankari Stage V             Vasanthapura                     
    GM Palaya                        Nagasandra                       
    Karuna Nagar                     Mico Layout                      
    Nehru Nagar                     2nd Phase Judicial Layout        
    Thyagaraja Nagar                 HAL 2nd Stage                    
    Narayanapura                     Marsur                           
    Tindlu                           Banjara Layout                   
    Kodigehalli                      Pattandur Agrahara               LB Shastri Nagar           
    '''
 
    Label(n,text=data).place(x=50,y=50)
  
    n.resizable(0,0)
    n.mainloop()

Button(root,text="areainfo",width=15,command=areainfo).place(x=420,y=70)




def info():
    n=Tk()
    n.geometry("800x600")
    n.configure(background="light green")
    Label(n, text="Information about Application", bg="light green",font=('Helvetica',15,'bold')).pack()
    data='''* House Price Prediction *
    Problemstatment:-\n By analyzing these house data we will determine the approximate price for the houses.\n
    Business Objective and Constraints:--\n
    1. The cost of a mis-classification can be high.\n
    2. There is strict latency concerns.\n
    3. From this project we will able to understand how 
    house prices depend on other factors.\n
    '''
 
    Label(n,text=data).place(x=50,y=50)
  
    n.resizable(0,0)
    n.mainloop()

Button(root,text="info",width=15,command=info).place(x=500,y=350)

def model():
    location=ln.get()
    bhk=bk.get()
    bath=bm.get()
    area=ts.get()
    f=open('finallr.pkl','rb')
    lr=pickle.load(f)
    cb=pd.DataFrame({'location':[location],'total_sqft':[float(area)],'bath':[int(bath)],'bhk':[int(bhk)]})
    #result=lr.predict([[int(area),int(bhk),int(bath)]])
    result=lr.predict(cb)
    print(result[0])
    final=result[0].round(2)
    l3.config(text=(str(final)+' Lakhs','location :'+str(location),'bhk :'+str(bhk),'bathrooms :'+str(bath),'total_square_fit :'+str(area)))
# database
    conn=mysql.connector.connect(user='root',password='Ganesh',host='localhost',database='houseprice')
    i_cursor = conn.cursor()
    qur1="INSERT INTO prediction(location,bhk,bath,area,final_result) VALUES('%s','%d','%d','%f','%f')"%(location,int(bhk),int(bath),float(area),final)
    i_cursor.execute(qur1)
    conn.commit()
    conn.close()
    




def clear():
    ln.set('')
    bk.set('')
    bm.set('')
    ts.set('')
    l3.config(text='')
Button(root,text="Predict Price",width=15,command=model).place(x=700,y=260)
Button(root,text="Clear Prediction",width=15,command=clear).place(x=700,y=300)
Button(root,text="termination",width=15,command=root.destroy).place(x=700,y=350)

#root.resizable(0,0)
root.mainloop()
# Out:
# 81.7238394061407
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-6b9e9ab4e073>", line 221, in model
#     result=lr.predict(cb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\metaestimators.py", line 120, in <lambda>
#     out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\pipeline.py", line 418, in predict
#     Xt = transform.transform(Xt)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py", line 565, in transform
#     Xs = self._fit_transform(X, None, _transform_one, fitted=True)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\sklearn\compose\_column_transformer.py", line 435, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
# ...
